# %%
# import pandas as pd
# df=pd.read_csv("data1.csv)

# %%
import pandas as pd

# %%
df=pd.read_csv("data1.csv")

# %%
df.columns
# Out:
# Index(['TV', 'Radio', 'Newspaper', 'Sales'], dtype='object')

# %%
df.head(5)
# Out:
#       TV  Radio  Newspaper  Sales
# 0  230.1   37.8       69.2   22.1
# 1   44.5   39.3       45.1   10.4
# 2   17.2   45.9       69.3   12.0
# 3  151.5   41.3       58.5   16.5
# 4  180.8   10.8       58.4   17.9

# %%
df.shape
# Out:
# (200, 4)

# %%
df.tail(4)
# Out:
#         TV  Radio  Newspaper  Sales
# 196   94.2    4.9        8.1   14.0
# 197  177.0    9.3        6.4   14.8
# 198  283.6   42.0       66.2   25.5
# 199  232.1    8.6        8.7   18.4

# %%
df.sample(2)
# Out:
#         TV  Radio  Newspaper  Sales
# 54   262.7   28.8       15.9   20.2
# 144   96.2   14.8       38.9   12.3

# %%
df.rename(columns={"Radio":"rr"})
# Out:
#         TV    rr  Newspaper  Sales
# 0    230.1  37.8       69.2   22.1
# 1     44.5  39.3       45.1   10.4
# 2     17.2  45.9       69.3   12.0
# 3    151.5  41.3       58.5   16.5
# 4    180.8  10.8       58.4   17.9
# ..     ...   ...        ...    ...
# 195   38.2   3.7       13.8    7.6
# 196   94.2   4.9        8.1   14.0
# 197  177.0   9.3        6.4   14.8
# 198  283.6  42.0       66.2   25.5
# 199  232.1   8.6        8.7   18.4
#
# [200 rows x 4 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   TV         200 non-null    float64
#  1   Radio      200 non-null    float64
#  2   Newspaper  200 non-null    float64
#  3   Sales      200 non-null    float64
# dtypes: float64(4)
# memory usage: 6.4 KB

# %%
df.describe()
# Out:
#                TV       Radio   Newspaper       Sales
# count  200.000000  200.000000  200.000000  200.000000
# mean   147.042500   23.264000   30.554000   15.130500
# std     85.854236   14.846809   21.778621    5.283892
# min      0.700000    0.000000    0.300000    1.600000
# 25%     74.375000    9.975000   12.750000   11.000000
# 50%    149.750000   22.900000   25.750000   16.000000
# 75%    218.825000   36.525000   45.100000   19.050000
# max    296.400000   49.600000  114.000000   27.000000

# %%
r=df.describe(include="all")

# %%
r.loc[["mean"]]
# Out:
#             TV   Radio  Newspaper    Sales
# mean  147.0425  23.264     30.554  15.1305

# %%
r.iloc[[0,1,3]]
# Out:
#              TV    Radio  Newspaper     Sales
# count  200.0000  200.000    200.000  200.0000
# mean   147.0425   23.264     30.554   15.1305
# min      0.7000    0.000      0.300    1.6000

# %%
pd.set_option('display.max_rows' , None)
pd.set_option('display.max_columns',None)
df[["Radio","TV"]]
# Out:
#      Radio     TV
# 0     37.8  230.1
# 1     39.3   44.5
# 2     45.9   17.2
# 3     41.3  151.5
# 4     10.8  180.8
# 5     48.9    8.7
# 6     32.8   57.5
# 7     19.6  120.2
# 8      2.1    8.6
# 9      2.6  199.8
# 10     5.8   66.1
# 11    24.0  214.7
# 12    35.1   23.8
# 13     7.6   97.5
# 14    32.9  204.1
# 15    47.7  195.4
# 16    36.6   67.8
# 17    39.6  281.4
# 18    20.5   69.2
# 19    23.9  147.3
# 20    27.7  218.4
# 21     5.1  237.4
# 22    15.9   13.2
# 23    16.9  228.3
# 24    12.6   62.3
# 25     3.5  262.9
# 26    29.3  142.9
# 27    16.7  240.1
# 28    27.1  248.8
# 29    16.0   70.6
# 30    28.3  292.9
# 31    17.4  112.9
# 32     1.5   97.2
# 33    20.0  265.6
# 34     1.4   95.7
# 35     4.1  290.7
# 36    43.8  266.9
# 37    49.4   74.7
# 38    26.7   43.1
# 39    37.7  228.0
# 40    22.3  202.5
# 41    33.4  177.0
# 42    27.7  293.6
# 43     8.4  206.9
# 44    25.7   25.1
# 45    22.5  175.1
# 46     9.9   89.7
# 47    41.5  239.9
# 48    15.8  227.2
# ...

# %%
df["Radio"].mean()
# Out:
# 23.264000000000006

# %%
df["Radio"].mode()
# Out:
# 0    4.1
# 1    5.7
# Name: Radio, dtype: float64

# %%
df["Radio"].median()
# Out:
# 22.9

# %%
df['Radio'] .value_counts()
# Out:
# Radio
# 4.1     3
# 5.7     3
# 13.9    2
# 14.3    2
# 36.9    2
#        ..
# 42.8    1
# 14.5    1
# 30.6    1
# 33.0    1
# 8.6     1
# Name: count, Length: 167, dtype: int64

# %%
df['Radio'].value_counts().plot(kind="bar" ,title="Radio" ,color= "red")
# Out:
# <Axes: title={'center': 'Radio'}, xlabel='Radio'>

# %%
df['Radio'].value_counts().plot(kind="line" ,title="Radio" ,color= "red")
# Out:
# <Axes: title={'center': 'Radio'}, xlabel='Radio'>

# %%
df['Radio'].value_counts().plot(kind="pie" ,title="Radio" ,color= "red")
# Out:
# <Axes: title={'center': 'Radio'}, ylabel='count'>

# %%
df.isnull().sum
# Out:
# <bound method DataFrame.sum of         TV  Radio  Newspaper  Sales
# 0    False  False      False  False
# 1    False  False      False  False
# 2    False  False      False  False
# 3    False  False      False  False
# 4    False  False      False  False
# ..     ...    ...        ...    ...
# 195  False  False      False  False
# 196  False  False      False  False
# 197  False  False      False  False
# 198  False  False      False  False
# 199  False  False      False  False
#
# [200 rows x 4 columns]>

# %%
df[df["Radio"].isnull()]
# Out:
# Empty DataFrame
# Columns: [TV, Radio, Newspaper, Sales]
# Index: []

# %%
df["final_price"] = df["Radio"].fillna(df["Radio"].mean())

# %%
df[df["Sales"].isnull()]
# Out:
# Empty DataFrame
# Columns: [TV, Radio, Newspaper, Sales, final_price]
# Index: []

# %%
df.groupby("TV").describe()
# Out:
#       Radio                                         Newspaper         ...  \
#       count  mean std   min   25%   50%   75%   max     count   mean  ...
# TV                                                                    ...
# 0.7     1.0  39.6 NaN  39.6  39.6  39.6  39.6  39.6       1.0    8.7  ...
# 4.1     1.0  11.6 NaN  11.6  11.6  11.6  11.6  11.6       1.0    5.7  ...
# 5.4     1.0  29.9 NaN  29.9  29.9  29.9  29.9  29.9       1.0    9.4  ...
# 7.3     1.0  28.1 NaN  28.1  28.1  28.1  28.1  28.1       1.0   41.4  ...
# 7.8     1.0  38.9 NaN  38.9  38.9  38.9  38.9  38.9       1.0   50.6  ...
# ...     ...   ...  ..   ...   ...   ...   ...   ...       ...    ...  ...
# 289.7   1.0  42.3 NaN  42.3  42.3  42.3  42.3  42.3       1.0   51.2  ...
# 290.7   1.0   4.1 NaN   4.1   4.1   4.1   4.1   4.1       1.0    8.5  ...
# 292.9   1.0  28.3 NaN  28.3  28.3  28.3  28.3  28.3       1.0   43.2  ...
# 293.6   1.0  27.7 NaN  27.7  27.7  27.7  27.7  27.7       1.0    1.8  ...
# ...

# %%
df.to_csv("data3.csv")
